# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
del df['Unnamed: 0']

# %%
del df['url_inmueble']

# %%
df
# Out:
#        id_realEstates  isNew                    realEstate_name  \
# 0           153771986  False            ferrari 57 inmobiliaria
# 1           153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           153430440  False                 look find boadilla
# 3           152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           153180188  False            ferrari 57 inmobiliaria
# ...               ...    ...                                ...
# 15330       153901377  False                infocasa consulting
# 15331       150394373  False                inmobiliaria pulpon
# 15332       153901397  False             tecnocasa torrelodones
# 15333       152607440  False                inmobiliaria pulpon
# 15334       153901356  False                infocasa consulting
#
#        phone_realEstate  rooms  bathrooms  surface   price  \
# 0           912177526.0    3.0        2.0    103.0  195000
# 1           916358736.0    3.0        1.0      NaN   89000
# ...

# %%
df['address']
# Out:
# 0        Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                         Calle Polvoranca, 6, Fuenlabrada
# 2                Calle Reyes Católicos, Boadilla del Monte
# 3                           Barrio San Andres, Fuenlabrada
# 4                                          Arganda del Rey
#                                ...
# 15330                                       Madrid Capital
# 15331                               Velilla de San Antonio
# 15332                                         Torrelodones
# 15333                               Velilla de San Antonio
# 15334              Paseo de la Castellana,  Madrid Capital
# Name: address, Length: 15335, dtype: object

# %%
df.columns
# Out:
# Index(['id_realEstates', 'isNew', 'realEstate_name', 'phone_realEstate',
#        'rooms', 'bathrooms', 'surface', 'price', 'date', 'description',
#        'address', 'country', 'level1', 'level2', 'level3', 'level4', 'level5',
#        'level6', 'level7', 'level8', 'upperLevel', 'countryId', 'level1Id',
#        'level2Id', 'level3Id', 'level4Id', 'level5Id', 'level6Id', 'level7Id',
#        'level8Id', 'accuracy', 'latitude', 'longitude', 'zipCode',
#        'customZone'],
#       dtype='object')

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
df['price'].max()
# Out:
# np.int64(8500000)

# %%
# Fila con el precio más alto
max_precio = df['price'].idxmax()

# Precio y a la dirección correspondiente
precio_maximo = df.loc[max_precio, 'price']
direccion_casa = df.loc[max_precio, 'address']

print(f"El precio más caro es: {precio_maximo}, y la dirección es: {direccion_casa}")
# Out:
# El precio más caro es: 8500000, y la dirección es: El Escorial

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# Fila con el precio más bajo
min_precio = df['price'].idxmin()

# Precio y a la dirección correspondiente
precio_maximo = df.loc[min_precio, 'price']
direccion_casa = df.loc[min_precio, 'address']

print(f"El precio más bajo es: {precio_maximo}, y la dirección es: {direccion_casa}")
# Out:
# El precio más bajo es: 0, y la dirección es: Parla

# %%
df
# Out:
#        id_realEstates  isNew                    realEstate_name  \
# 0           153771986  False            ferrari 57 inmobiliaria
# 1           153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           153430440  False                 look find boadilla
# 3           152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           153180188  False            ferrari 57 inmobiliaria
# ...               ...    ...                                ...
# 15330       153901377  False                infocasa consulting
# 15331       150394373  False                inmobiliaria pulpon
# 15332       153901397  False             tecnocasa torrelodones
# 15333       152607440  False                inmobiliaria pulpon
# 15334       153901356  False                infocasa consulting
#
#        phone_realEstate  rooms  bathrooms  surface   price  \
# 0           912177526.0    3.0        2.0    103.0  195000
# 1           916358736.0    3.0        1.0      NaN   89000
# ...

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
superficie_min = df.sort_values(by='surface', ascending=True)
superficie_max = df.sort_values(by='surface', ascending=False)

print(f"La casa mas grande esta ubicada en {superficie_max.iat[0,12]} y su superficie es de {superficie_max.iat[0,8]} metros")
print(f"La casa mas pequeña esta ubicada en {superficie_min.iat[0,12]} y su superficie es de {superficie_min.iat[0,8]} metros ")
# Out:
# La casa mas grande esta ubicada en Madrid y su superficie es de 2019-12-25T18:30:00Z metros
# La casa mas pequeña esta ubicada en Madrid y su superficie es de 2019-12-28T19:04:44.6433814Z metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
valor = df.loc[0, 'level5']
num_filas=df.shape[0]
print (num_filas)
df.tail()


for i in range(num_filas):
  print(f"{df.loc[i,'level5']}, ")
# Out:
# 15335
# Arganda del Rey,
# Fuenlabrada,
# Boadilla del Monte,
# Fuenlabrada,
# Arganda del Rey,
# Las Rozas de Madrid,
# Las Rozas de Madrid,
# Las Rozas de Madrid,
# Las Rozas de Madrid,
#  Madrid Capital,
#  Madrid Capital,
# Villaviciosa de Odón,
# Pinto,
# Valdemoro,
# Navalcarnero,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
# Pozuelo de Alarcón,
# Torrejón de Ardoz,
# Navalagamella,
# San Sebastián de los Reyes,
#  Madrid Capital,
# Rivas-vaciamadrid,
# Alpedrete,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
# Móstoles,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
# San Fernando de Henares,
# Coslada,
#  Madrid Capital,
# Becerril de la Sierra,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
# Alcalá de Henares,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
#  Madrid Capital,
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
df.isnull().any()
# Out:
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# zipCode              True
# customZone           True
# dtype: bool

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
sinfilas_nan = df.dropna(how = "all")
sincolumnas_nan= sinfilas_nan.dropna(axis=1, how = "all")

print(df.shape)
print (sincolumnas_nan.shape)
# Out:
# (15335, 37)
# (15335, 35)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
df_arro = df[df['level5']=='Arroyomolinos (Madrid)']

mean_price = df_arro['price'].mean()

print (mean_price)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 5))

plt.hist(df_arro['price'],bins=60,alpha=0.7)
plt.title("Precios en Arroyomolinos")
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
df_val = df[df['level5']=='Valdemorillo']
df_gal = df[df['level5']=='Galapagar']

mean_price_Valdemorillo = df_val['price'].mean()
mean_price_Galapagar= df_gal['price'].mean()

print(mean_price_Valdemorillo)
print(mean_price_Galapagar)
# Out:
# 363860.2931034483
# 360063.20238095237

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
df_val['pps'] = df_val['price']/df_val['surface']

df_gal['pps'] = df_gal['price']/df_gal['surface']

mean_price_Valdemorillo = df_val['pps'].mean()
mean_price_Galapagar= df_gal['pps'].mean()

print(mean_price_Valdemorillo)
print(mean_price_Galapagar)
# Out:
# 1317.9502109024986
# 1606.3240303094024
# /tmp/ipykernel_671/1487872113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val['pps'] = df_val['price']/df_val['surface']
# /tmp/ipykernel_671/1487872113.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gal['pps'] = df_gal['price']/df_gal['surface']

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
filtrado = df.dropna(subset=['surface','price'])

acotado = filtrado[(filtrado['surface']< 3000) & (filtrado['price']>15000) ]

plt.figure(figsize = (30,10))

plt.scatter(acotado['price'], acotado['surface'], label = 'Precio vs superficie')

plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
df_filtrado = df.dropna(subset =['realEstate_name'])

num_agencias = df_filtrado['realEstate_name'].nunique()

print(num_agencias)
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
mayor_cantidad=df['level5'].value_counts()
print(mayor_cantidad)
# Out:
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Fresno de Torote           1
# Pinilla del Valle          1
# Rascafría                  1
# La Hiruela                 1
# Montejo de la Sierra       1
# Name: count, Length: 168, dtype: int64

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
cinturon_sur = ['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón']

df_filtrado_ = df[df['level5'].isin(cinturon_sur)]

print (df_filtrado_)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

filtrado_Fuenla = df_filtrado_[df_filtrado_['level5'].isin(['Fuenlabrada'])]
filtrado_Leganés = df_filtrado_[df_filtrado_['level5'].isin(['Leganés'])]
filtrado_Alcorcón = df_filtrado_[df_filtrado_['level5'].isin(['Alcorcón'])]
filtrado_Getafe = df_filtrado_[df_filtrado_['level5'].isin(['Getafe'])]


medianas = [
    filtrado_Fuenla['price'].median(),
    filtrado_Alcorcón['price'].median(),
    filtrado_Leganés['price'].median(),  
    filtrado_Getafe['price'].median()
]
lugares = ['Fuenlabrada', 'Alcorcón', 'Leganés', 'Getafe']

print(medianas)
plt.bar(lugares, medianas)
plt.show()
# Out:
# [np.float64(155000.0), np.float64(179500.0), np.float64(169950.0), np.float64(285305.0)]

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
df_filtrado_.head()

mean_price_ej16=df_filtrado_['price'].mean()
variance_price_ej16= df_filtrado_['price'].var()

mean_rooms_ej16=df_filtrado_['rooms'].mean()
variance_rooms_ej16= df_filtrado_['rooms'].var()

mean_surface_ej16=df_filtrado_['surface'].mean()
variance_surface_ej16= df_filtrado_['surface'].var()

mean_bathrooms_ej16= df_filtrado_['bathrooms'].mean()
variance_bathrooms_ej16=df_filtrado_['bathrooms'].var()

print(f'la media y varianza del precio son ({mean_price_ej16,variance_price_ej16})')
print(f'la media y varianza de habitaciones son ({mean_rooms_ej16,variance_rooms_ej16})')
print(f'la media y varianza del área son ({mean_surface_ej16,variance_rooms_ej16})')
print(f'la media y varianza de baños son ({mean_bathrooms_ej16,variance_bathrooms_ej16})')
# Out:
# la media y varianza del precio son ((np.float64(223094.48070562293), np.float64(14921367508.04902)))
# la media y varianza de habitaciones son ((np.float64(3.0177383592017737), np.float64(0.7188858892927542)))
# la media y varianza del área son ((np.float64(111.75222363405337), np.float64(0.7188858892927542)))
# la media y varianza de baños son ((np.float64(1.633221850613155), np.float64(0.5717968625577321)))

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
print (filtrado_Alcorcón['price'].max())
print (filtrado_Fuenla['price'].max())
print (filtrado_Leganés['price'].max())
print (filtrado_Getafe['price'].max())
# Out:
# 950000
# 490000
# 650000
# 1050000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
norm_Alcorcón =((filtrado_Alcorcón['price']-filtrado_Alcorcón['price'].min())/(filtrado_Alcorcón['price'].max() - filtrado_Alcorcón['price'].min()))

norm_Fuenlabrada =((filtrado_Fuenla['price']-filtrado_Fuenla['price'].min())/(filtrado_Fuenla['price'].max() - filtrado_Fuenla['price'].min()))

norm_Leganés =((filtrado_Leganés['price']-filtrado_Leganés['price'].min())/(filtrado_Leganés['price'].max() - filtrado_Leganés['price'].min()))

norm_Geta =((filtrado_Getafe['price']-filtrado_Getafe['price'].min())/(filtrado_Getafe['price'].max() - filtrado_Getafe['price'].min()))

plt.figure(figsize = (20,5))

plt.hist(norm_Alcorcón, bins=60, color='black', alpha=0.5, label='Alcorcón')
plt.hist(norm_Fuenlabrada, bins=60,color='red', alpha=0.5, label='Fueblabrada')
plt.hist(norm_Leganés, bins=60,color='orange', alpha=0.5, label='Leganés')
plt.hist(norm_Geta, bins=60, alpha=0.5, color='yellow', label='Getafe')


plt.legend()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
df_get = filtrado_Getafe
df_alc= filtrado_Alcorcón

df_get['pps']= df_get['price']/df_get['surface']
df_alc['pps']= df_alc['price']/df_alc['surface']

print(df_get['pps'].mean())
print(df_alc['pps'].mean())
# Out:
# 2066.314949251463
# 2239.302480199618
# /tmp/ipykernel_671/96117611.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_get['pps']= df_get['price']/df_get['surface']
# /tmp/ipykernel_671/96117611.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alc['pps']= df_alc['price']/df_alc['surface']

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
fig, ax = plt.subplots (2,2, figsize = (30,10))

ax[0, 0].scatter(filtrado_Alcorcón['surface'], filtrado_Alcorcón['price'], color = 'red')
ax[0, 0].set_title('Alcorcón: Superficie vs Precio')
ax[0, 0].set_xlabel('Superficie (m²)')
ax[0, 0].set_ylabel('Precio (€)')
ax[0, 0].set_xlim(0, 300)

ax[0, 1].scatter(filtrado_Getafe['surface'], filtrado_Getafe['price'], color = 'blue')
ax[0, 1].set_title('Getafe: Superficie vs Precio')
ax[0, 1].set_xlabel('Superficie (m²)')
ax[0, 1].set_ylabel('Precio (€)')
ax[0, 1].set_xlim(40, 300)

ax[1, 0].scatter(filtrado_Fuenla['surface'], filtrado_Fuenla['price'], color = 'green')
ax[1, 0].set_title('Fuenlabrada: Superficie vs Precio')
ax[1, 0].set_xlabel('Superficie (m²)')
ax[1, 0].set_ylabel('Precio (€)')
ax[1, 0].set_xlim(40, 300)

ax[1, 1].scatter(filtrado_Leganés['surface'], filtrado_Leganés['price'], color = 'brown')
ax[1, 1].set_title('Leganés: Superficie vs Precio')
ax[1, 1].set_xlabel('Superficie (m²)')
ax[1, 1].set_ylabel('Precio (€)')
ax[1, 1].set_xlim(40, 300)

plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
